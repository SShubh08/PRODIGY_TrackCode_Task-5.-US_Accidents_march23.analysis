# %%
US Accident March23 Analysis /Task5

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_US = pd.read_csv(r"C:\Users\SHUBHAM KUMBHAR\Downloads\archive\US_Accidents_March23.csv")

# %%
df_US.head()
# Out:
#     ID   Source  Severity           Start_Time             End_Time  \
# 0  A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Roundabout  \
# 0  39.865147 -84.058723      NaN      NaN          0.01  ...      False
# 1  39.928059 -82.831184      NaN      NaN          0.01  ...      False
# 2  39.063148 -84.032608      NaN      NaN          0.01  ...      False
# 3  39.747753 -84.205582      NaN      NaN          0.01  ...      False
# 4  39.627781 -84.188354      NaN      NaN          0.01  ...      False
#
#   Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# ...

# %%
df_US.tail()
# Out:
#                 ID   Source  Severity           Start_Time  \
# 7728389  A-7777757  Source1         2  2019-08-23 18:03:25
# 7728390  A-7777758  Source1         2  2019-08-23 19:11:30
# 7728391  A-7777759  Source1         2  2019-08-23 19:00:21
# 7728392  A-7777760  Source1         2  2019-08-23 19:00:21
# 7728393  A-7777761  Source1         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat  Start_Lng   End_Lat    End_Lng  \
# 7728389  2019-08-23 18:32:01   34.00248 -117.37936  33.99888 -117.37094
# 7728390  2019-08-23 19:38:23   32.76696 -117.14806  32.76555 -117.15363
# 7728391  2019-08-23 19:28:49   33.77545 -117.84779  33.77740 -117.85727
# 7728392  2019-08-23 19:29:42   33.99246 -118.40302  33.98311 -118.39565
# 7728393  2019-08-23 19:21:31   34.13393 -117.23092  34.13736 -117.23934
#
#          Distance(mi)  ... Roundabout Station   Stop Traffic_Calming  \
# 7728389         0.543  ...      False   False  False           False
# ...

# %%
df_US.columns
# Out:
# Index(['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description',
#        'Street', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
df_US.dtypes.value_counts()
# Out:
# object     20
# bool       13
# float64    12
# int64       1
# Name: count, dtype: int64

# %%
df_US.shape
# Out:
# (7728394, 46)

# %%
df_US.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  7.728394e+06  7.728394e+06  7.728394e+06  4.325632e+06  4.325632e+06
# mean   2.212384e+00  3.620119e+01 -9.470255e+01  3.626183e+01 -9.572557e+01
# std    4.875313e-01  5.076079e+00  1.739176e+01  5.272905e+00  1.810793e+01
# min    1.000000e+00  2.455480e+01 -1.246238e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.339963e+01 -1.172194e+02  3.346207e+01 -1.177543e+02
# 50%    2.000000e+00  3.582397e+01 -8.776662e+01  3.618349e+01 -8.802789e+01
# 75%    2.000000e+00  4.008496e+01 -8.035368e+01  4.017892e+01 -8.024709e+01
# max    4.000000e+00  4.900220e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)  Temperature(F)  Wind_Chill(F)   Humidity(%)  \
# count  7.728394e+06    7.564541e+06   5.729375e+06  7.554250e+06
# mean   5.618423e-01    6.166329e+01   5.825105e+01  6.483104e+01
# std    1.776811e+00    1.901365e+01   2.238983e+01  2.282097e+01
# ...

# %%
df_US.State.unique
# Out:
# <bound method Series.unique of 0          OH
# 1          OH
# 2          OH
# 3          OH
# 4          OH
#            ..
# 7728389    CA
# 7728390    CA
# 7728391    CA
# 7728392    CA
# 7728393    CA
# Name: State, Length: 7728394, dtype: object>

# %%
df1=df_US[df_US['State']=='CA']

# %%
df1['IDD'] = df1['ID'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
# Out:
# C:\Users\SHUBHAM KUMBHAR\AppData\Local\Temp\ipykernel_23660\1955134751.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['IDD'] = df1['ID'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)

# %%
df1
# Out:
#                 ID   Source  Severity           Start_Time  \
# 728          A-729  Source2         3  2016-06-21 10:34:40
# 729          A-730  Source2         3  2016-06-21 10:30:16
# 730          A-731  Source2         2  2016-06-21 10:49:14
# 731          A-732  Source2         3  2016-06-21 10:41:42
# 732          A-733  Source2         2  2016-06-21 10:16:26
# ...            ...      ...       ...                  ...
# 7728389  A-7777757  Source1         2  2019-08-23 18:03:25
# 7728390  A-7777758  Source1         2  2019-08-23 19:11:30
# 7728391  A-7777759  Source1         2  2019-08-23 19:00:21
# 7728392  A-7777760  Source1         2  2019-08-23 19:00:21
# 7728393  A-7777761  Source1         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat   Start_Lng   End_Lat    End_Lng  \
# 728      2016-06-21 11:04:40  38.085300 -122.233017       NaN        NaN
# 729      2016-06-21 11:16:39  37.631813 -122.084167       NaN        NaN
# ...

# %%
df1.head()
# Out:
#         ID   Source  Severity           Start_Time             End_Time  \
# 728  A-729  Source2         3  2016-06-21 10:34:40  2016-06-21 11:04:40
# 729  A-730  Source2         3  2016-06-21 10:30:16  2016-06-21 11:16:39
# 730  A-731  Source2         2  2016-06-21 10:49:14  2016-06-21 11:19:14
# 731  A-732  Source2         3  2016-06-21 10:41:42  2016-06-21 11:11:42
# 732  A-733  Source2         2  2016-06-21 10:16:26  2016-06-21 11:04:16
#
#      Start_Lat   Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Station  \
# 728  38.085300 -122.233017      NaN      NaN           0.0  ...   False
# 729  37.631813 -122.084167      NaN      NaN           0.0  ...   False
# 730  37.896564 -122.070717      NaN      NaN           0.0  ...   False
# 731  37.334255 -122.032471      NaN      NaN           0.0  ...   False
# 732  37.250729 -121.910713      NaN      NaN           0.0  ...   False
#
#       Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# ...

# %%
df1.shape
# Out:
# (1741433, 47)

# %%
df1.shape
# Out:
# (1741433, 47)

# %%
df1.columns
# Out:
# Index(['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description',
#        'Street', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight', 'IDD'],
#       dtype='object')

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
len(df1)
# Out:
# 1741433

# %%
len(df_US)
# Out:
# 7728394

# %%
df_US.isna
# Out:
# <bound method DataFrame.isna of                 ID   Source  Severity           Start_Time  \
# 0              A-1  Source2         3  2016-02-08 05:46:00
# 1              A-2  Source2         2  2016-02-08 06:07:59
# 2              A-3  Source2         2  2016-02-08 06:49:27
# 3              A-4  Source2         3  2016-02-08 07:23:34
# 4              A-5  Source2         2  2016-02-08 07:39:07
# ...            ...      ...       ...                  ...
# 7728389  A-7777757  Source1         2  2019-08-23 18:03:25
# 7728390  A-7777758  Source1         2  2019-08-23 19:11:30
# 7728391  A-7777759  Source1         2  2019-08-23 19:00:21
# 7728392  A-7777760  Source1         2  2019-08-23 19:00:21
# 7728393  A-7777761  Source1         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat   Start_Lng   End_Lat    End_Lng  \
# 0        2016-02-08 11:00:00  39.865147  -84.058723       NaN        NaN
# 1        2016-02-08 06:37:59  39.928059  -82.831184       NaN        NaN
# ...

# %%
this multiplies the proportions by 100 to convert them into percentages.
The result is a Series where each value represents the percentage of missing values
for the corresponding column.
# Out:
#   Cell In[28], line 1
#     this multiplies the proportions by 100 to convert them into percentages.
#          ^
# SyntaxError: invalid syntax

# %%
df1.isna().sum()/len(df1)*100
# Out:
# ID                        0.000000
# Source                    0.000000
# Severity                  0.000000
# Start_Time                0.000000
# End_Time                  0.000000
# Start_Lat                 0.000000
# Start_Lng                 0.000000
# End_Lat                  36.598078
# End_Lng                  36.598078
# Distance(mi)              0.000000
# Description               0.000172
# Street                    0.140229
# City                      0.000632
# County                    0.000000
# State                     0.000000
# Zipcode                   0.034282
# Country                   0.000000
# Timezone                  0.034282
# Airport_Code              0.121509
# Weather_Timestamp         1.883793
# Temperature(F)            2.639723
# Wind_Chill(F)            29.341640
# Humidity(%)               2.775932
# Pressure(in)              2.131922
# Visibility(mi)            2.304137
# Wind_Direction            2.652356
# Wind_Speed(mph)           9.353848
# ...

# %%
df1['Weather_Condition'].value_counts()
# Out:
# Weather_Condition
# Fair                       772394
# Clear                      253189
# Mostly Cloudy              142762
# Cloudy                     138400
# Partly Cloudy              117470
#                             ...
# Dust Whirls                     1
# Light Snow with Thunder         1
# Wintry Mix / Windy              1
# Sand / Windy                    1
# Light Thunderstorm              1
# Name: count, Length: 87, dtype: int64

# %%
cities = df1['City'].unique()
len(cities)
# Out:
# 1269

# %%
df_num=df1.select_dtypes(np.number)
col_name=[]
length=[]

for i in df_num.columns:
    col_name.append(i)
    length.append(len(df_num[i].unique()))
df_2=pd.DataFrame(zip(col_name,length),columns=['feature','count_of_unique_values'])
df_2
# Out:
#               feature  count_of_unique_values
# 0            Severity                       4
# 1           Start_Lat                  498509
# 2           Start_Lng                  501661
# 3             End_Lat                  350773
# 4             End_Lng                  356822
# 5        Distance(mi)                   13409
# 6      Temperature(F)                     571
# 7       Wind_Chill(F)                     403
# 8         Humidity(%)                     101
# 9        Pressure(in)                     835
# 10     Visibility(mi)                      64
# 11    Wind_Speed(mph)                     122
# 12  Precipitation(in)                      92
# 13                IDD                 1741433

# %%
plt.figure(figsize=(15 ,9))
sns.heatmap(df_num.corr() , annot=True)
# Out:
# <Axes: >

# %%
accidents_by_cities = df1['City'].value_counts()
accidents_by_cities
# Out:
# City
# Los Angeles                 156491
# Sacramento                   66264
# San Diego                    55504
# San Jose                     34531
# Riverside                    26317
#                              ...
# Shoshone                         1
# Holtville                        1
# South Santa Clara Valley         1
# Heber                            1
# West Santa Cruz                  1
# Name: count, Length: 1268, dtype: int64

# %%
accidents_by_cities[:10]
# Out:
# City
# Los Angeles       156491
# Sacramento         66264
# San Diego          55504
# San Jose           34531
# Riverside          26317
# Oakland            23571
# San Bernardino     21990
# Bakersfield        21390
# Anaheim            21293
# Long Beach         21040
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(8,5))
accidents_by_cities[:10].plot(kind='bar',color='red')
ax.set(title = 'Top 10 cities By Number of Accidents',
       xlabel = 'Cities',
       ylabel = 'Accidents Count')
ax.set_facecolor('darkgray')
plt.show()

# %%
df1['Start_Time'].dtypes
# Out:
# dtype('O')

# %%
df1['End_Time'].dtypes
# Out:
# dtype('O')

# %%
df1['Start_Time'][2408]
# Out:
# '2016-07-07 16:34:34'

# %%
df1['End_Time'][2408]
# Out:
# '2016-07-07 17:49:34'

# %%
del df1['Start_Time']
del df1['End_Time']

# %%
# %matplotlib inline
import os

# %%
fig, ax = plt.subplots(figsize=(8, 5))
df1['Weather_Condition'].value_counts().sort_values(ascending=False)[:20].plot(kind='bar',color='red')
ax.set(title='Weather Conditions at Time of Accident Occurrence',
       xlabel='Weather',
       ylabel='Accidents Count')
ax.set_facecolor('darkgrey')
plt.show()

# %%
most accidents happened when the weather was 'fair'.
Perhaps weather (bad weather) 
was not a big contributing factor to accidents.

# %%
fig, ax = plt.subplots(figsize=(8, 5))
df1['Weather_Condition'].value_counts().sort_values(ascending=False)[:5].plot(kind='bar',color='red')
ax.set(title='Top 5 Weather Conditions at Time of Accident Occurrence',
       xlabel='Weather',
       ylabel='Accidents Count')
ax.set_facecolor('darkgrey')
plt.show()
